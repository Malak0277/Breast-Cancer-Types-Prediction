# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.inspection import permutation_importance
from sklearn.tree import plot_tree
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, classification_report, ConfusionMatrixDisplay

# %% [markdown]
# # Define Dataset

# %%
df = pd.read_csv("/content/breast-cancer_cleaned(1).csv")
df
# Out:
#      texture_mean  symmetry_mean  fractal_dimension_mean  texture_se  \
# 0       -2.073335       2.217515                2.255747   -0.565265
# 1       -0.353632       0.001392               -0.868652   -0.876244
# 2        0.456187       0.939685               -0.398008   -0.780083
# 3        0.253732       0.155462                0.046836   -0.110409
# 4       -1.151816      -0.009560               -0.562450   -0.790244
# ..            ...            ...                     ...         ...
# 564      0.721473      -0.312589               -0.931027    0.071025
# 565      2.085134      -0.217664               -1.058611    0.322856
# 566      2.045574      -0.809117               -0.895587   -0.257371
# 567      2.336457       2.137194                1.043695    0.686088
# 568      1.221792      -0.820070               -0.561032    0.383092
#
#       area_se  smoothness_se  concavity_se  concave points_se  symmetry_se  \
# 0   -0.321821      -0.214002      0.724026           0.660820     1.148757
# 1    0.742402      -0.605351     -0.440780           0.260162    -0.805450
# 2    0.557852      -0.297005      0.213076           1.424827     0.237036
# 3   -0.288378       0.689702      0.819518           1.115007    -0.069777
# 4    0.156716       1.483067      0.828471           1.144205    -0.361092
# ..        ...            ...           ...                ...          ...
# 564  0.350640       1.086384      0.666001           2.067178    -1.138416
# 565 -0.131594      -0.424010      0.252202           0.808431    -0.189161
# 566  0.180698      -0.379342      0.510827           0.612157    -0.891416
# 567  0.183955      -0.173000      1.302285           0.785721     0.326634
# 568 -0.466152       0.049342     -1.057501          -1.913447     0.752830
#
#      fractal_dimension_se  smoothness_worst  symmetry_worst  \
# 0                0.907083          1.307686        1.139636
# 1               -0.099444         -0.375612       -0.243890
# 2                0.293559          0.527407        1.152255
# 3                0.267687          0.749217       -0.115114
# 4                0.499328          0.220556       -0.868353
# ..                    ...               ...             ...
# 564              0.167980          0.378365       -1.360158
# 565             -0.490556         -0.691230       -0.531855
# 566              0.036727         -0.809587       -1.104549
# 567              0.904057          1.430427        1.919083
# 568             -0.382754         -1.859019       -0.048138
#
#      fractal_dimension_worst  diagnosis
# 0                   1.937015          1
# 1                   0.281190          1
# 2                   0.201391          1
# 3                   0.230872          1
# 4                  -0.397100          1
# ..                       ...        ...
# 564                -0.709091          1
# 565                -0.973978          1
# 566                -0.318409          1
# 567                 0.936537          1
# 568                -0.751207          0
#
# [569 rows x 14 columns]

# %% [markdown]
# # Training Classifiers

# %% [markdown]
# ### Evaluation function

# %%
def evaluate_model(y_true, y_pred, model_name):
    print(f"\n{model_name} Performance:\n")

    cm = confusion_matrix(y_true, y_pred)
    tn, fp, fn, tp = cm.ravel()

    accuracy = accuracy_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0  # Manual calc for specificity

    print(f"Accuracy: {accuracy * 100:.2f}%")
    print(f"Error Rate: {(1-accuracy) * 100:.2f}%")
    print(f"Sensitivity (Recall): {recall * 100:.2f}%")
    print(f"Specificity: {specificity * 100:.2f}%")
    print(f"Precision: {precision * 100:.2f}%")

    print('\nClassification Report:\n', classification_report(y_true, y_pred))

    print('Confusion Matrix:')
    cm_percentage = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100
    disp = ConfusionMatrixDisplay(confusion_matrix=cm_percentage, display_labels=np.unique(y_true))
    disp.plot(cmap='Blues', values_format=".2f")  # Display values with 2 decimal places
    plt.title(f"Confusion Matrix for {model_name} (Percentage)")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.show()

# %% [markdown]
# ### Function to plot hyperparameters vs accuracy

# %%
def plot_hyperparameter_results(grid_search, model_name):
    # Extract results
    results = grid_search.cv_results_

    # Get mean training and validation scores
    mean_train_scores = results['mean_train_score']  # Training accuracy
    mean_val_scores = results['mean_test_score']    # Validation accuracy
    param_combinations = results['params']          # Hyperparameter combinations

    # Plot training and validation accuracy
    indices = np.arange(len(param_combinations))
    plt.figure(figsize=(20, 7))
    plt.plot(indices, mean_train_scores, marker='o', linestyle='-', color='blue', label='Training Accuracy')
    plt.plot(indices, mean_val_scores, marker='o', linestyle='--', color='orange', label='Validation Accuracy')

    # Add labels, legend, and grid
    plt.xlabel('Hyperparameter Configuration Index')
    plt.ylabel('Accuracy')
    plt.title(f'Training and Validation Accuracy vs. Hyperparameter Configuration ({model_name})')
    plt.xticks(indices, labels=indices)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()


    # Print the configurations and their scores
    for i, params in enumerate(param_combinations):
        print()
        print(f"Configuration {i}: {params}")
        print(f"   Training Accuracy: {mean_train_scores[i]:.4f}", f"\t\t   Validation Accuracy: {mean_val_scores[i]:.4f}")

# %% [markdown]
# ### Split data into train - test sets

# %%
X = df.drop('diagnosis', axis = 1)
y = df['diagnosis']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# Split data into training (80%), testing (20%)

# %% [markdown]
# The training set will be splited into train - val to get best hyperparameters using cross validation.

# %% [markdown]
# ## Decision Tree Classifier

# %% [markdown]
# ### Training

# %% [markdown]
# #### Intialize model

# %%
# Initialize the Decision Tree model with a fixed random seed for reproducibility
dt_model = DecisionTreeClassifier(random_state=42)

# %% [markdown]
# #### Get best hyperparameters using grid search

# %%
# Hyperparameter grid for tuning the Decision Tree
dt_param_grid = {
    'criterion': ['gini', 'entropy'],     # Use both Gini impurity and entropy for splitting nodes
    'max_depth': [3, 4],               # Test different maximum depths of the tree
    'min_samples_split': [30, 35],        # Minimum samples required to split an internal node
    'min_samples_leaf': [5, 10, 15],      # Minimum samples required to be at a leaf node
    'ccp_alpha': [0.02],            # Pruning parameter to control overfitting
    'max_features': [None, 'sqrt', 'log2']          # Added max features
}

# %%
# Set up GridSearchCV to tune hyperparameters with 5-fold cross-validation
dt_grid_search = GridSearchCV(
    estimator=dt_model,                 # Decision Tree model
    param_grid=dt_param_grid,           # Hyperparameter grid for tuning
    scoring='accuracy',                 # Evaluate model based on accuracy score
    cv=5,                               # 5-fold cross-validation
    return_train_score=True,            # Return training scores
    n_jobs=-1,                          # Use all CPU cores for parallel processing
    verbose=2                           # Display progress during the search
)

# %% [markdown]
# #### Fit model to get best hyperparameters

# %%
dt_grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'ccp_alpha': [0.02], 'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 4],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_leaf': [5, 10, 15],
#                          'min_samples_split': [30, 35]},
#              return_train_score=True, scoring='accuracy', verbose=2)

# %%
plot_hyperparameter_results(dt_grid_search, "Decision Tree")
# Out:
# Configuration 0: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9154 		   Validation Accuracy: 0.8879
#
# Configuration 1: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9154 		   Validation Accuracy: 0.8879
#
# Configuration 2: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9088 		   Validation Accuracy: 0.8769
#
# Configuration 3: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9088 		   Validation Accuracy: 0.8769
#
# Configuration 4: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9033 		   Validation Accuracy: 0.8615
#
# Configuration 5: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9033 		   Validation Accuracy: 0.8615
#
# Configuration 6: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.8890 		   Validation Accuracy: 0.8681
#
# Configuration 7: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.8890 		   Validation Accuracy: 0.8681
#
# Configuration 8: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.8984 		   Validation Accuracy: 0.8681
#
# Configuration 9: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.8984 		   Validation Accuracy: 0.8681
#
# Configuration 10: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.8962 		   Validation Accuracy: 0.8725
#
# Configuration 11: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.8962 		   Validation Accuracy: 0.8725
#
# Configuration 12: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.8890 		   Validation Accuracy: 0.8681
#
# Configuration 13: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.8890 		   Validation Accuracy: 0.8681
#
# Configuration 14: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.8984 		   Validation Accuracy: 0.8681
#
# Configuration 15: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.8984 		   Validation Accuracy: 0.8681
#
# Configuration 16: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.8962 		   Validation Accuracy: 0.8725
#
# Configuration 17: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.8962 		   Validation Accuracy: 0.8725
#
# Configuration 18: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9154 		   Validation Accuracy: 0.8879
#
# Configuration 19: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9154 		   Validation Accuracy: 0.8879
#
# Configuration 20: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9088 		   Validation Accuracy: 0.8769
#
# Configuration 21: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9088 		   Validation Accuracy: 0.8769
#
# Configuration 22: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9033 		   Validation Accuracy: 0.8615
#
# Configuration 23: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9033 		   Validation Accuracy: 0.8615
#
# Configuration 24: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.8978 		   Validation Accuracy: 0.8747
#
# Configuration 25: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9005 		   Validation Accuracy: 0.8791
#
# Configuration 26: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.8929 		   Validation Accuracy: 0.8857
#
# Configuration 27: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.8945 		   Validation Accuracy: 0.8791
#
# Configuration 28: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.8852 		   Validation Accuracy: 0.8615
#
# Configuration 29: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.8885 		   Validation Accuracy: 0.8681
#
# Configuration 30: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.8978 		   Validation Accuracy: 0.8747
#
# Configuration 31: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9005 		   Validation Accuracy: 0.8791
#
# Configuration 32: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.8929 		   Validation Accuracy: 0.8857
#
# Configuration 33: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.8945 		   Validation Accuracy: 0.8791
#
# Configuration 34: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.8852 		   Validation Accuracy: 0.8615
#
# Configuration 35: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.8885 		   Validation Accuracy: 0.8681
#
# Configuration 36: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9264 		   Validation Accuracy: 0.8989
#
# Configuration 37: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9264 		   Validation Accuracy: 0.8989
#
# Configuration 38: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9225 		   Validation Accuracy: 0.8923
#
# Configuration 39: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9225 		   Validation Accuracy: 0.8923
#
# Configuration 40: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9115 		   Validation Accuracy: 0.8659
#
# Configuration 41: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9115 		   Validation Accuracy: 0.8659
#
# Configuration 42: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9093 		   Validation Accuracy: 0.8747
#
# Configuration 43: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9093 		   Validation Accuracy: 0.8747
#
# Configuration 44: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9088 		   Validation Accuracy: 0.8769
#
# Configuration 45: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9088 		   Validation Accuracy: 0.8769
#
# Configuration 46: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9044 		   Validation Accuracy: 0.8791
#
# Configuration 47: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9044 		   Validation Accuracy: 0.8791
#
# Configuration 48: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9093 		   Validation Accuracy: 0.8747
#
# Configuration 49: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9093 		   Validation Accuracy: 0.8747
#
# Configuration 50: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9088 		   Validation Accuracy: 0.8769
#
# Configuration 51: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9088 		   Validation Accuracy: 0.8769
#
# Configuration 52: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9044 		   Validation Accuracy: 0.8791
#
# Configuration 53: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9044 		   Validation Accuracy: 0.8791
#
# Configuration 54: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9302 		   Validation Accuracy: 0.8945
#
# Configuration 55: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9297 		   Validation Accuracy: 0.8923
#
# Configuration 56: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9269 		   Validation Accuracy: 0.8945
#
# Configuration 57: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9264 		   Validation Accuracy: 0.8923
#
# Configuration 58: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9115 		   Validation Accuracy: 0.8681
#
# Configuration 59: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9115 		   Validation Accuracy: 0.8681
#
# Configuration 60: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9132 		   Validation Accuracy: 0.8879
#
# Configuration 61: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9132 		   Validation Accuracy: 0.8857
#
# Configuration 62: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9071 		   Validation Accuracy: 0.9011
#
# Configuration 63: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9060 		   Validation Accuracy: 0.8989
#
# Configuration 64: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9044 		   Validation Accuracy: 0.9033
#
# Configuration 65: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9044 		   Validation Accuracy: 0.9033
#
# Configuration 66: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9132 		   Validation Accuracy: 0.8879
#
# Configuration 67: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9132 		   Validation Accuracy: 0.8857
#
# Configuration 68: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9071 		   Validation Accuracy: 0.9011
#
# Configuration 69: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9060 		   Validation Accuracy: 0.8989
#
# Configuration 70: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9044 		   Validation Accuracy: 0.9033
#
# Configuration 71: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9044 		   Validation Accuracy: 0.9033

# %%
# Get the best model based on the grid search
best_dt_model = dt_grid_search.best_estimator_
dt_grid_search.best_params_
# Out:
# {'ccp_alpha': 0.02,
#  'criterion': 'entropy',
#  'max_depth': 4,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 15,
#  'min_samples_split': 30}

# %% [markdown]
# ### Important features

# %%
# Feature Importance
importance_tree = pd.Series(best_dt_model.feature_importances_, index=X.columns).sort_values(ascending=False)
print("Feature Importance (Decision Tree):")
print(importance_tree)

# Bar Plot
importance_tree.plot(kind="bar", color="skyblue", title="Feature Importance (Decision Tree)")
plt.xlabel("Features")
plt.ylabel("Importance Score")
plt.show()
# Out:
# Feature Importance (Decision Tree):
# area_se                    0.653147
# smoothness_worst           0.121637
# concavity_se               0.087887
# symmetry_worst             0.084731
# texture_mean               0.052599
# symmetry_mean              0.000000
# fractal_dimension_mean     0.000000
# texture_se                 0.000000
# smoothness_se              0.000000
# concave points_se          0.000000
# symmetry_se                0.000000
# fractal_dimension_se       0.000000
# fractal_dimension_worst    0.000000
# dtype: float64

# %%
dt_grid_search.best_index_
# Out:
# 64

# %% [markdown]
# ### Training Evaluation

# %% [markdown]
# #### Grid search best model validation accuracy

# %%
# Get the index of the best configuration
best_config_index = dt_grid_search.best_index_
best_val_accuracy = dt_grid_search.cv_results_['mean_test_score'][best_config_index]

# Print the best configuration and its corresponding accuracy
print(f"Validation accuracy for best configuration: {best_val_accuracy * 100:.2f}%")
# Out:
# Validation accuracy for best configuration: 90.33%

# %% [markdown]
# ### Testing Evaluation

# %%
# Predict labels for the test set using the best Decision Tree model
y_test_pred_dt = best_dt_model.predict(X_test)
# Evaluate the model on the test set
evaluate_model(y_test, y_test_pred_dt, "Tuned Decision Tree")
# Out:
# Tuned Decision Tree Performance:
#
# Accuracy: 82.46%
# Error Rate: 17.54%
# Sensitivity (Recall): 66.67%
# Specificity: 91.67%
# Precision: 82.35%
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.92      0.87        72
#            1       0.82      0.67      0.74        42
#
#     accuracy                           0.82       114
#    macro avg       0.82      0.79      0.80       114
# weighted avg       0.82      0.82      0.82       114
#
# Confusion Matrix:

# %% [markdown]
# ### Plot Decision Tree

# %%
plt.figure(figsize=(30,15))
plot_tree(best_dt_model, filled=True, feature_names=X_train.columns, class_names=["Benign", "Malignant"], rounded=True, fontsize=15)

# Add a legend with colors for the classes
plt.legend(handles=[plt.Line2D([0], [0], marker='o', markerfacecolor=color, markersize=25) for color in ['orange', 'lightblue']],
           labels=["Benign", "Malignant"], loc="best", fontsize=25)
plt.show()

# %% [markdown]
# ## KNN Classifier

# %% [markdown]
# ### Training using grid search

# %% [markdown]
# #### Get best hyperparameters using grid search

# %%
# Create KNN classifier model
knn_model = KNeighborsClassifier()

# %%
# Hyperparameter grid for tuning the Decision Tree
knn_param_grid = {
    # List of possible values for the number of neighbors to consider during classification
    'n_neighbors': [3, 5, 9, 15, 21],

    # List of distance metrics to use when calculating the distance between data points
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

# %%
# Set up GridSearchCV to search for the best hyperparameters
knn_grid_search = GridSearchCV(
    estimator=knn_model,                # KNN model
    param_grid=knn_param_grid,          # Hyperparameter grid to search
    scoring='f1_weighted',              # Use F1 weighted score as evaluation metric
    cv=5,                               # 5-fold cross-validation
    return_train_score=True             # Return training scores
)

# %% [markdown]
# #### Fit model to get best hyperparameters

# %%
knn_grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'metric': ['euclidean', 'manhattan', 'minkowski'],
#                          'n_neighbors': [3, 5, 9, 15, 21]},
#              return_train_score=True, scoring='f1_weighted')

# %%
plot_hyperparameter_results(knn_grid_search, "Decision Tree")
# Out:
# Configuration 0: {'metric': 'euclidean', 'n_neighbors': 3}
#    Training Accuracy: 0.9409 		   Validation Accuracy: 0.8916
#
# Configuration 1: {'metric': 'euclidean', 'n_neighbors': 5}
#    Training Accuracy: 0.9344 		   Validation Accuracy: 0.9010
#
# Configuration 2: {'metric': 'euclidean', 'n_neighbors': 9}
#    Training Accuracy: 0.9267 		   Validation Accuracy: 0.8959
#
# Configuration 3: {'metric': 'euclidean', 'n_neighbors': 15}
#    Training Accuracy: 0.9302 		   Validation Accuracy: 0.9053
#
# Configuration 4: {'metric': 'euclidean', 'n_neighbors': 21}
#    Training Accuracy: 0.9269 		   Validation Accuracy: 0.9031
#
# Configuration 5: {'metric': 'manhattan', 'n_neighbors': 3}
#    Training Accuracy: 0.9392 		   Validation Accuracy: 0.8961
#
# Configuration 6: {'metric': 'manhattan', 'n_neighbors': 5}
#    Training Accuracy: 0.9410 		   Validation Accuracy: 0.9050
#
# Configuration 7: {'metric': 'manhattan', 'n_neighbors': 9}
#    Training Accuracy: 0.9333 		   Validation Accuracy: 0.9068
#
# Configuration 8: {'metric': 'manhattan', 'n_neighbors': 15}
#    Training Accuracy: 0.9333 		   Validation Accuracy: 0.9115
#
# Configuration 9: {'metric': 'manhattan', 'n_neighbors': 21}
#    Training Accuracy: 0.9172 		   Validation Accuracy: 0.9115
#
# Configuration 10: {'metric': 'minkowski', 'n_neighbors': 3}
#    Training Accuracy: 0.9409 		   Validation Accuracy: 0.8916
#
# Configuration 11: {'metric': 'minkowski', 'n_neighbors': 5}
#    Training Accuracy: 0.9344 		   Validation Accuracy: 0.9010
#
# Configuration 12: {'metric': 'minkowski', 'n_neighbors': 9}
#    Training Accuracy: 0.9267 		   Validation Accuracy: 0.8959
#
# Configuration 13: {'metric': 'minkowski', 'n_neighbors': 15}
#    Training Accuracy: 0.9302 		   Validation Accuracy: 0.9053
#
# Configuration 14: {'metric': 'minkowski', 'n_neighbors': 21}
#    Training Accuracy: 0.9269 		   Validation Accuracy: 0.9031

# %%
best_knn_model = knn_grid_search.best_estimator_
knn_grid_search.best_params_
# Out:
# {'metric': 'manhattan', 'n_neighbors': 15}

# %% [markdown]
# ### Important features

# %%
# Permutation Importance
perm_importance_knn = permutation_importance(best_knn_model, X, y, n_repeats=10, random_state=42)
importance_knn = pd.Series(perm_importance_knn.importances_mean, index=X.columns).sort_values(ascending=False)
print("Feature Importance (KNN - Permutation Importance):")
print(importance_knn)

# Bar Plot
importance_knn.plot(kind="bar", color="green", title="Feature Importance (KNN)")
plt.xlabel("Features")
plt.ylabel("Importance Score")
plt.show()
# Out:
# Feature Importance (KNN - Permutation Importance):
# area_se                    0.034622
# concave points_se          0.023199
# fractal_dimension_mean     0.022320
# texture_mean               0.021441
# smoothness_worst           0.017223
# concavity_se               0.008436
# smoothness_se              0.002285
# symmetry_worst            -0.000176
# symmetry_se               -0.001230
# fractal_dimension_worst   -0.005272
# texture_se                -0.006151
# fractal_dimension_se      -0.006503
# symmetry_mean             -0.008612
# dtype: float64

# %%
knn_grid_search.best_index_
# Out:
# 8

# %% [markdown]
# #### Grid search best model validation accuracy

# %%
best_knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=15)

# %% [markdown]
# ### Training Evaluation

# %%
# Get the index of the best configuration
best_config_index = knn_grid_search.best_index_
best_val_accuracy = knn_grid_search.cv_results_['mean_test_score'][best_config_index]

# Print the best configuration and its corresponding accuracy
print(f"Validation accuracy for best configuration: {best_val_accuracy * 100:.2f}%")
# Out:
# Validation accuracy for best configuration: 91.15%

# %% [markdown]
# ### Testing Evaluation

# %%
# Predict labels for the test set using the best KNN model
y_test_pred_knn = best_knn_model.predict(X_test)
# Evaluate the performance of the tuned KNN model on the test set
evaluate_model(y_test, y_test_pred_knn, "KNN")
# Out:
# KNN Performance:
#
# Accuracy: 85.09%
# Error Rate: 14.91%
# Sensitivity (Recall): 66.67%
# Specificity: 95.83%
# Precision: 90.32%
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89        72
#            1       0.90      0.67      0.77        42
#
#     accuracy                           0.85       114
#    macro avg       0.87      0.81      0.83       114
# weighted avg       0.86      0.85      0.84       114
#
# Confusion Matrix:

# %% [markdown]
# ### Training using manual search

# %% [markdown]
# #### Split train set to train - validate sets

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# %% [markdown]
# #### Get best k with respect to training and validation accuracy

# %%
# Initialize results storage
manual_results = {
    'train_scores': [],
    'val_scores': [],
    'param_combinations': []
}
best_score = 0
best_params = None
best_knn_model = None
best_difference = float('inf')

# Iterate over n_neighbors and metrics
for metric in ['euclidean', 'manhattan']:
    for n in range(3, 30, 2):
        knn = KNeighborsClassifier(n_neighbors=n, weights='uniform', metric=metric)
        knn.fit(X_train, y_train)

        # Predict on the training set and validation set
        train_pred = knn.predict(X_train)
        val_pred = knn.predict(X_val)

        # Calculate accuracy
        train_accuracy = round(accuracy_score(y_train, train_pred), 5)
        val_accuracy = round(accuracy_score(y_val, val_pred), 5)

        # Store the results
        manual_results['train_scores'].append(train_accuracy)
        manual_results['val_scores'].append(val_accuracy)
        manual_results['param_combinations'].append({'n_neighbors': n, 'metric': metric})

        # Calculate the difference between training and validation accuracy
        difference = abs(train_accuracy - val_accuracy)

        # Update the best model criteria: prioritize high validation accuracy with minimal difference
        if val_accuracy > best_score or (val_accuracy == best_score and difference < best_difference):
            best_score = val_accuracy
            best_difference = difference
            best_params = {'n_neighbors': n, 'metric': metric}
            best_knn_model = knn

# Print the best results
print("Best Parameters:", best_params)
print("Best Validation Accuracy:", best_score)
print("Training vs Validation Accuracy Difference:", best_difference)
# Out:
# Best Parameters: {'n_neighbors': 15, 'metric': 'manhattan'}
# Best Validation Accuracy: 0.93407
# Training vs Validation Accuracy Difference: 0.0027400000000000757

# %%
def plot_manual_results_with_metric(manual_results, model_name):
    # Extract results
    train_scores = manual_results['train_scores']
    val_scores = manual_results['val_scores']
    param_combinations = manual_results['param_combinations']  # List of dictionaries with n_neighbors and metric

    # Separate results by metric
    metrics = list(set([param['metric'] for param in param_combinations]))
    plt.figure(figsize=(15, 7))

    for metric in metrics:
        # Filter results for the current metric
        indices = [i for i, param in enumerate(param_combinations) if param['metric'] == metric]
        n_neighbors = [param_combinations[i]['n_neighbors'] for i in indices]
        train_metric_scores = [train_scores[i] for i in indices]
        val_metric_scores = [val_scores[i] for i in indices]

        # Plot training and validation scores for the current metric
        plt.plot(n_neighbors, train_metric_scores, marker='o', linestyle='-', label=f'Train ({metric})')
        plt.plot(n_neighbors, val_metric_scores, marker='o', linestyle='--', label=f'Validation ({metric})')

    # Add labels, legend, and grid
    plt.xlabel('Number of Neighbors (n_neighbors)')
    plt.ylabel('Accuracy')
    plt.title(f'Training and Validation Accuracy vs. n_neighbors ({model_name})')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    # Print detailed results for each metric
    for metric in metrics:
        print(f"Results for metric: {metric}")
        for i, param in enumerate(param_combinations):
            if param['metric'] == metric:
                print(f"  n_neighbors = {param['n_neighbors']}, Training Accuracy: {train_scores[i]:.5f}, Validation Accuracy: {val_scores[i]:.5f}")
        print("-" * 50)

# Example usage:
plot_manual_results_with_metric(manual_results, model_name="K-Nearest Neighbors")
# Out:
# Results for metric: manhattan
#   n_neighbors = 3, Training Accuracy: 0.93956, Validation Accuracy: 0.89011
#   n_neighbors = 5, Training Accuracy: 0.94505, Validation Accuracy: 0.90110
#   n_neighbors = 7, Training Accuracy: 0.93407, Validation Accuracy: 0.90110
#   n_neighbors = 9, Training Accuracy: 0.93681, Validation Accuracy: 0.91209
#   n_neighbors = 11, Training Accuracy: 0.93681, Validation Accuracy: 0.92308
#   n_neighbors = 13, Training Accuracy: 0.93132, Validation Accuracy: 0.93407
#   n_neighbors = 15, Training Accuracy: 0.93681, Validation Accuracy: 0.93407
#   n_neighbors = 17, Training Accuracy: 0.93132, Validation Accuracy: 0.92308
#   n_neighbors = 19, Training Accuracy: 0.93132, Validation Accuracy: 0.92308
#   n_neighbors = 21, Training Accuracy: 0.93132, Validation Accuracy: 0.93407
#   n_neighbors = 23, Training Accuracy: 0.92582, Validation Accuracy: 0.93407
#   n_neighbors = 25, Training Accuracy: 0.92857, Validation Accuracy: 0.93407
#   n_neighbors = 27, Training Accuracy: 0.92308, Validation Accuracy: 0.92308
#   n_neighbors = 29, Training Accuracy: 0.92308, Validation Accuracy: 0.92308
# --------------------------------------------------
# Results for metric: euclidean
#   n_neighbors = 3, Training Accuracy: 0.93956, Validation Accuracy: 0.84615
#   n_neighbors = 5, Training Accuracy: 0.93956, Validation Accuracy: 0.85714
#   n_neighbors = 7, Training Accuracy: 0.94505, Validation Accuracy: 0.87912
#   n_neighbors = 9, Training Accuracy: 0.92582, Validation Accuracy: 0.89011
#   n_neighbors = 11, Training Accuracy: 0.92857, Validation Accuracy: 0.91209
#   n_neighbors = 13, Training Accuracy: 0.92857, Validation Accuracy: 0.90110
#   n_neighbors = 15, Training Accuracy: 0.93132, Validation Accuracy: 0.93407
#   n_neighbors = 17, Training Accuracy: 0.92857, Validation Accuracy: 0.93407
#   n_neighbors = 19, Training Accuracy: 0.92308, Validation Accuracy: 0.93407
#   n_neighbors = 21, Training Accuracy: 0.92033, Validation Accuracy: 0.92308
#   n_neighbors = 23, Training Accuracy: 0.92308, Validation Accuracy: 0.91209
#   n_neighbors = 25, Training Accuracy: 0.92308, Validation Accuracy: 0.92308
#   n_neighbors = 27, Training Accuracy: 0.92582, Validation Accuracy: 0.92308
#   n_neighbors = 29, Training Accuracy: 0.92857, Validation Accuracy: 0.92308
# --------------------------------------------------

# %% [markdown]
# #### fit model using best parameter

# %%
# Extract the best parameters
best_n_neighbors, best_metric = best_params['n_neighbors'], best_params['metric']

# %%
# Initialize the KNN model with the best parameters
best_manual_knn_model = KNeighborsClassifier(n_neighbors=best_n_neighbors, weights='uniform', metric=best_metric)

# %%
# Fit the model on the entire training set
best_manual_knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=15)

# %% [markdown]
# #### Training Evaluation

# %%
y_val_pred_knn = best_manual_knn_model.predict(X_val)
evaluate_model(y_val, y_val_pred_knn, "KNN")
# Out:
# KNN Performance:
#
# Accuracy: 93.41%
# Error Rate: 6.59%
# Sensitivity (Recall): 84.85%
# Specificity: 98.28%
# Precision: 96.55%
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95        58
#            1       0.97      0.85      0.90        33
#
#     accuracy                           0.93        91
#    macro avg       0.94      0.92      0.93        91
# weighted avg       0.94      0.93      0.93        91
#
# Confusion Matrix:

# %% [markdown]
# #### Test Evaluation

# %%
y_test_pred_knn = best_manual_knn_model.predict(X_test)
evaluate_model(y_test, y_test_pred_knn, "KNN")
# Out:
# KNN Performance:
#
# Accuracy: 86.84%
# Error Rate: 13.16%
# Sensitivity (Recall): 73.81%
# Specificity: 94.44%
# Precision: 88.57%
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90        72
#            1       0.89      0.74      0.81        42
#
#     accuracy                           0.87       114
#    macro avg       0.87      0.84      0.85       114
# weighted avg       0.87      0.87      0.87       114
#
# Confusion Matrix:

# %% [markdown]
# ## Naïve Bayes Classifier

# %% [markdown]
# ### Split data into Train, Validation, and Test Sets

# %%
X = df.drop('diagnosis', axis = 1)
y = df['diagnosis']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# %% [markdown]
# Split data into training (80%), testing (20%)
#
# Then training into training (80%), validation (20%)
#
# 64% training - 16% validation - 20% testing

# %% [markdown]
# ### Intialize model

# %%
nb_model = GaussianNB()

# %% [markdown]
# #### Fit model

# %%
nb_model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# ### Training Evaluation

# %%
y_val_pred = nb_model.predict(X_val)
evaluate_model(y_val, y_val_pred, "Naïve Bayes")
# Out:
# Naïve Bayes Performance:
#
# Accuracy: 91.21%
# Error Rate: 8.79%
# Sensitivity (Recall): 90.91%
# Specificity: 91.38%
# Precision: 85.71%
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93        58
#            1       0.86      0.91      0.88        33
#
#     accuracy                           0.91        91
#    macro avg       0.90      0.91      0.91        91
# weighted avg       0.91      0.91      0.91        91
#
# Confusion Matrix:

# %% [markdown]
# ### Testing Evaluation

# %%
y_test_pred_nb = nb_model.predict(X_test)
evaluate_model(y_test, y_test_pred_nb, "Naïve Bayes")
# Out:
# Naïve Bayes Performance:
#
# Accuracy: 87.72%
# Error Rate: 12.28%
# Sensitivity (Recall): 80.95%
# Specificity: 91.67%
# Precision: 85.00%
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90        72
#            1       0.85      0.81      0.83        42
#
#     accuracy                           0.88       114
#    macro avg       0.87      0.86      0.87       114
# weighted avg       0.88      0.88      0.88       114
#
# Confusion Matrix:

# %% [markdown]
# ### Important features

# %%
# Extract means and variances for each class
means = nb_model.theta_  # Class-wise means of features
variances = nb_model.var_  # Class-wise variances of features

# Compute feature relevance as the difference in means normalized by variance
feature_relevance = np.abs(means[0] - means[1]) / np.sqrt(variances[0] + variances[1])

importance_nb = pd.Series(feature_relevance, index=X.columns).sort_values(ascending=False)

# Display the feature importance
print("Feature Importance (Naive Bayes):")
print(importance_nb)

# Bar Plot
importance_nb.plot(kind="bar", color="gold", title="Feature Importance (Naive Bayes)")
plt.xlabel("Features")
plt.ylabel("Importance Score")
plt.show()
# Out:
# Feature Importance (Naive Bayes):
# area_se                    1.272617
# concave points_se          0.798141
# texture_mean               0.777093
# smoothness_worst           0.722413
# concavity_se               0.702288
# symmetry_worst             0.573627
# fractal_dimension_worst    0.524033
# symmetry_mean              0.490825
# symmetry_se                0.293341
# fractal_dimension_se       0.225045
# smoothness_se              0.092243
# fractal_dimension_mean     0.052013
# texture_se                 0.033318
# dtype: float64

# %% [markdown]
# ## Multi‐Layer Perceptron

# %% [markdown]
# ### Intialize model

# %%
mlp_model = MLPClassifier()

# %% [markdown]
# #### Get best hyperparameters using grid search

# %%
mlp_param_grid = {
    'hidden_layer_sizes': [(10,), (20,), (10, 10)],  # Smaller networks
    'activation': ['relu'],  # Stick with ReLU for simpler decision boundaries
    'solver': ['adam'],
    'max_iter': [200],  # Reduce iterations
    'alpha': [0.01, 0.1],  # Stronger regularization
    'batch_size': [32, 64],  # Explicit batch sizes for better regularization
    'early_stopping': [True],  # Add early stopping
    'validation_fraction': [0.2]  # Set aside validation data
}

# %%
# Set up GridSearchCV to tune hyperparameters with 5-fold cross-validation
mlp_grid_search = GridSearchCV(
    estimator=mlp_model,
    param_grid=mlp_param_grid,
    scoring='f1_weighted',  # Evaluation metric
    cv=5,  # 5-fold cross-validation
    return_train_score=True,
    n_jobs=-1  # Parallelize the process if you have multiple CPU cores
)

# %% [markdown]
# #### Fit model to get best hyperparameters

# %%
mlp_grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=MLPClassifier(), n_jobs=-1,
#              param_grid={'activation': ['relu'], 'alpha': [0.01, 0.1],
#                          'batch_size': [32, 64], 'early_stopping': [True],
#                          'hidden_layer_sizes': [(10,), (20,), (10, 10)],
#                          'max_iter': [200], 'solver': ['adam'],
#                          'validation_fraction': [0.2]},
#              return_train_score=True, scoring='f1_weighted')

# %%
plot_hyperparameter_results(mlp_grid_search, "MLP")
# Out:
# Configuration 0: {'activation': 'relu', 'alpha': 0.01, 'batch_size': 32, 'early_stopping': True, 'hidden_layer_sizes': (10,), 'max_iter': 200, 'solver': 'adam', 'validation_fraction': 0.2}
#    Training Accuracy: 0.9149 		   Validation Accuracy: 0.9084
#
# Configuration 1: {'activation': 'relu', 'alpha': 0.01, 'batch_size': 32, 'early_stopping': True, 'hidden_layer_sizes': (20,), 'max_iter': 200, 'solver': 'adam', 'validation_fraction': 0.2}
#    Training Accuracy: 0.8992 		   Validation Accuracy: 0.8975
#
# Configuration 2: {'activation': 'relu', 'alpha': 0.01, 'batch_size': 32, 'early_stopping': True, 'hidden_layer_sizes': (10, 10), 'max_iter': 200, 'solver': 'adam', 'validation_fraction': 0.2}
#    Training Accuracy: 0.9114 		   Validation Accuracy: 0.8913
#
# Configuration 3: {'activation': 'relu', 'alpha': 0.01, 'batch_size': 64, 'early_stopping': True, 'hidden_layer_sizes': (10,), 'max_iter': 200, 'solver': 'adam', 'validation_fraction': 0.2}
#    Training Accuracy: 0.8790 		   Validation Accuracy: 0.8476
#
# Configuration 4: {'activation': 'relu', 'alpha': 0.01, 'batch_size': 64, 'early_stopping': True, 'hidden_layer_sizes': (20,), 'max_iter': 200, 'solver': 'adam', 'validation_fraction': 0.2}
#    Training Accuracy: 0.8828 		   Validation Accuracy: 0.9028
#
# Configuration 5: {'activation': 'relu', 'alpha': 0.01, 'batch_size': 64, 'early_stopping': True, 'hidden_layer_sizes': (10, 10), 'max_iter': 200, 'solver': 'adam', 'validation_fraction': 0.2}
#    Training Accuracy: 0.7861 		   Validation Accuracy: 0.7818
#
# Configuration 6: {'activation': 'relu', 'alpha': 0.1, 'batch_size': 32, 'early_stopping': True, 'hidden_layer_sizes': (10,), 'max_iter': 200, 'solver': 'adam', 'validation_fraction': 0.2}
#    Training Accuracy: 0.9061 		   Validation Accuracy: 0.8803
#
# Configuration 7: {'activation': 'relu', 'alpha': 0.1, 'batch_size': 32, 'early_stopping': True, 'hidden_layer_sizes': (20,), 'max_iter': 200, 'solver': 'adam', 'validation_fraction': 0.2}
#    Training Accuracy: 0.8806 		   Validation Accuracy: 0.8706
#
# Configuration 8: {'activation': 'relu', 'alpha': 0.1, 'batch_size': 32, 'early_stopping': True, 'hidden_layer_sizes': (10, 10), 'max_iter': 200, 'solver': 'adam', 'validation_fraction': 0.2}
#    Training Accuracy: 0.8318 		   Validation Accuracy: 0.8029
#
# Configuration 9: {'activation': 'relu', 'alpha': 0.1, 'batch_size': 64, 'early_stopping': True, 'hidden_layer_sizes': (10,), 'max_iter': 200, 'solver': 'adam', 'validation_fraction': 0.2}
#    Training Accuracy: 0.7198 		   Validation Accuracy: 0.6938
#
# Configuration 10: {'activation': 'relu', 'alpha': 0.1, 'batch_size': 64, 'early_stopping': True, 'hidden_layer_sizes': (20,), 'max_iter': 200, 'solver': 'adam', 'validation_fraction': 0.2}
#    Training Accuracy: 0.8549 		   Validation Accuracy: 0.8380
#
# Configuration 11: {'activation': 'relu', 'alpha': 0.1, 'batch_size': 64, 'early_stopping': True, 'hidden_layer_sizes': (10, 10), 'max_iter': 200, 'solver': 'adam', 'validation_fraction': 0.2}
#    Training Accuracy: 0.8918 		   Validation Accuracy: 0.8581

# %%
# Get the best model based on the grid search
best_mlp_model = mlp_grid_search.best_estimator_
mlp_grid_search.best_params_
# Out:
# {'activation': 'relu',
#  'alpha': 0.01,
#  'batch_size': 32,
#  'early_stopping': True,
#  'hidden_layer_sizes': (10,),
#  'max_iter': 200,
#  'solver': 'adam',
#  'validation_fraction': 0.2}

# %%
# Permutation Importance
perm_importance_mlp = permutation_importance(best_mlp_model, X, y, n_repeats=10, random_state=42)
importance_mlp = pd.Series(perm_importance_mlp.importances_mean, index=X.columns).sort_values(ascending=False)
print("Feature Importance (MLP - Permutation Importance):")
print(importance_mlp)

# Bar Plot
importance_mlp.plot(kind="bar", color="purple", title="Feature Importance (MLP)")
plt.xlabel("Features")
plt.ylabel("Importance Score")
plt.show()
# Out:
# Feature Importance (MLP - Permutation Importance):
# texture_mean               0.089279
# fractal_dimension_mean     0.052548
# smoothness_worst           0.028471
# concave points_se          0.020035
# symmetry_se                0.015466
# symmetry_worst             0.013357
# concavity_se               0.012830
# symmetry_mean              0.007733
# area_se                    0.007381
# fractal_dimension_worst    0.006503
# fractal_dimension_se       0.002636
# texture_se                -0.001054
# smoothness_se             -0.002109
# dtype: float64

# %%
mlp_grid_search.best_index_
# Out:
# 0

# %% [markdown]
# ### Training Evaluation

# %% [markdown]
# #### Grid search best model validation accuracy

# %%
# Get the index of the best configuration
best_config_index = mlp_grid_search.best_index_
best_val_accuracy = mlp_grid_search.cv_results_['mean_test_score'][best_config_index]

# Print the best configuration and its corresponding accuracy
print(f"Validation accuracy for best configuration: {best_val_accuracy * 100:.2f}%")
# Out:
# Validation accuracy for best configuration: 90.84%

# %% [markdown]
# ### Testing Evaluation

# %%
y_test_pred_MLP = best_mlp_model.predict(X_test)
evaluate_model(y_test, y_test_pred_MLP, "MLP")
# Out:
# MLP Performance:
#
# Accuracy: 82.46%
# Error Rate: 17.54%
# Sensitivity (Recall): 69.05%
# Specificity: 90.28%
# Precision: 80.56%
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.90      0.87        72
#            1       0.81      0.69      0.74        42
#
#     accuracy                           0.82       114
#    macro avg       0.82      0.80      0.81       114
# weighted avg       0.82      0.82      0.82       114
#
# Confusion Matrix:

# %%
# Grids hyperparameter
svm_param_grid = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf'],
    'gamma': [0.1, 0.01, 0.001]
}

# %%
# Set up GridSearchCV for SVM
svm_model = SVC(random_state=42)
svm_grid_search = GridSearchCV(estimator=svm_model, param_grid=svm_param_grid, scoring='f1_weighted', cv=5, return_train_score=True)

# %%
svm_grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(random_state=42),
#              param_grid={'C': [0.1, 1, 10], 'gamma': [0.1, 0.01, 0.001],
#                          'kernel': ['linear', 'rbf']},
#              return_train_score=True, scoring='f1_weighted')

# %%
plot_hyperparameter_results(svm_grid_search, "SVM")
# Out:
# Configuration 0: {'C': 0.1, 'gamma': 0.1, 'kernel': 'linear'}
#    Training Accuracy: 0.9448 		   Validation Accuracy: 0.9330
#
# Configuration 1: {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
#    Training Accuracy: 0.9088 		   Validation Accuracy: 0.8920
#
# Configuration 2: {'C': 0.1, 'gamma': 0.01, 'kernel': 'linear'}
#    Training Accuracy: 0.9448 		   Validation Accuracy: 0.9330
#
# Configuration 3: {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
#    Training Accuracy: 0.5021 		   Validation Accuracy: 0.4914
#
# Configuration 4: {'C': 0.1, 'gamma': 0.001, 'kernel': 'linear'}
#    Training Accuracy: 0.9448 		   Validation Accuracy: 0.9330
#
# Configuration 5: {'C': 0.1, 'gamma': 0.001, 'kernel': 'rbf'}
#    Training Accuracy: 0.4791 		   Validation Accuracy: 0.4791
#
# Configuration 6: {'C': 1, 'gamma': 0.1, 'kernel': 'linear'}
#    Training Accuracy: 0.9600 		   Validation Accuracy: 0.9308
#
# Configuration 7: {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
#    Training Accuracy: 0.9641 		   Validation Accuracy: 0.9278
#
# Configuration 8: {'C': 1, 'gamma': 0.01, 'kernel': 'linear'}
#    Training Accuracy: 0.9600 		   Validation Accuracy: 0.9308
#
# Configuration 9: {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
#    Training Accuracy: 0.9286 		   Validation Accuracy: 0.9223
#
# Configuration 10: {'C': 1, 'gamma': 0.001, 'kernel': 'linear'}
#    Training Accuracy: 0.9600 		   Validation Accuracy: 0.9308
#
# Configuration 11: {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
#    Training Accuracy: 0.5356 		   Validation Accuracy: 0.5213
#
# Configuration 12: {'C': 10, 'gamma': 0.1, 'kernel': 'linear'}
#    Training Accuracy: 0.9636 		   Validation Accuracy: 0.9201
#
# Configuration 13: {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
#    Training Accuracy: 0.9966 		   Validation Accuracy: 0.9257
#
# Configuration 14: {'C': 10, 'gamma': 0.01, 'kernel': 'linear'}
#    Training Accuracy: 0.9636 		   Validation Accuracy: 0.9201
#
# Configuration 15: {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
#    Training Accuracy: 0.9586 		   Validation Accuracy: 0.9447
#
# Configuration 16: {'C': 10, 'gamma': 0.001, 'kernel': 'linear'}
#    Training Accuracy: 0.9636 		   Validation Accuracy: 0.9201
#
# Configuration 17: {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
#    Training Accuracy: 0.9287 		   Validation Accuracy: 0.9277

# %%
best_svm_model = svm_grid_search.best_estimator_

# %% [markdown]
# ### Important Features

# %%
# Permutation Importance
perm_importance_svm_rbf = permutation_importance(best_svm_model, X, y, n_repeats=10, random_state=42)
importance_rbf = pd.Series(perm_importance_svm_rbf.importances_mean, index=X.columns).sort_values(ascending=False)

# Display the feature importance
print("Feature Importance (SVM):")
print(importance_rbf)

# Bar Plot
importance_rbf.plot(kind="bar", color="teal", title="Feature Importance (SVM)")
plt.xlabel("Features")
plt.ylabel("Importance Score")
plt.show()
# Out:
# Feature Importance (SVM):
# area_se                    0.072935
# smoothness_worst           0.069244
# texture_mean               0.062039
# concave points_se          0.051845
# fractal_dimension_mean     0.031634
# smoothness_se              0.025132
# concavity_se               0.020387
# symmetry_mean              0.006327
# symmetry_se                0.005272
# symmetry_worst             0.004921
# fractal_dimension_worst    0.004569
# texture_se                -0.000703
# fractal_dimension_se      -0.001406
# dtype: float64

# %%
svm_grid_search.best_params_
svm_grid_search.best_index_
# Out:
# 15

# %%
# Get the index of the best configuration
best_config2_index = svm_grid_search.best_index_
best_val2_accuracy = svm_grid_search.cv_results_['mean_test_score'][best_config2_index]

# Print the best configuration and its corresponding accuracy
print(f"Validation accuracy for best configuration: {best_val2_accuracy * 100:.2f}%")
# Out:
# Validation accuracy for best configuration: 94.47%

# %%
y_test_pred_SVM = best_svm_model.predict(X_test)
evaluate_model(y_test, y_test_pred_SVM, "SVM")
# Out:
# SVM Performance:
#
# Accuracy: 93.86%
# Error Rate: 6.14%
# Sensitivity (Recall): 83.33%
# Specificity: 100.00%
# Precision: 100.00%
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        72
#            1       1.00      0.83      0.91        42
#
#     accuracy                           0.94       114
#    macro avg       0.96      0.92      0.93       114
# weighted avg       0.94      0.94      0.94       114
#
# Confusion Matrix:

# %% [markdown]
# ## Models Comparisions

# %%
# Extract weighted average metrics
metrics = ["precision", "recall", "f1-score"]
x_labels = ["Precision", "Recall", "F1-Score"]

# %%
# To plot histogram
x = np.arange(len(metrics))
width = 0.15

# %% [markdown]
# ### Validation Weighted Metrics

# %%
# Classification reports for testing
report_test_svm = classification_report(y_test, y_test_pred_SVM, output_dict=True)
report_test_nb = classification_report(y_test, y_test_pred_nb, output_dict=True)
report_test_knn = classification_report(y_test, y_test_pred_knn, output_dict=True)
report_test_dt = classification_report(y_test, y_test_pred_dt, output_dict=True)
report_test_mlp = classification_report(y_test, y_test_pred_MLP, output_dict=True)

# %%
# Testing metrics
svm_test_metrics = [report_test_svm["weighted avg"][metric] for metric in metrics]
nb_test_metrics = [report_test_nb["weighted avg"][metric] for metric in metrics]
knn_test_metrics = [report_test_knn["weighted avg"][metric] for metric in metrics]
dt_test_metrics = [report_test_dt["weighted avg"][metric] for metric in metrics]
mlp_test_metrics = [report_test_mlp["weighted avg"][metric] for metric in metrics]  # Extracted MLP metrics

# %%
# Plotting
plt.figure(figsize=(14, 7))
x_offset = [-2, -1, 0, 1, 2]  # Adjusted x offsets for 5 models
colors = ["pink", "lightcoral", "orchid", "hotpink", "plum"]   # Added color for MLP
labels = ["SVM (Testing)", "Naïve Bayes (Testing)", "KNN (Testing)", "Decision Tree (Testing)", "MLP (Testing)"]
all_metrics = [svm_test_metrics, nb_test_metrics, knn_test_metrics, dt_test_metrics, mlp_test_metrics]

# Bar plot for each model
for offset, metrics, color, label in zip(x_offset, all_metrics, colors, labels):
    plt.bar(x + offset * width, metrics, width, label=label, color=color)

plt.ylabel("Score")
plt.title("Weighted Metrics - Testing Set")
plt.xticks(x, x_labels)
plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %%
svm_test_accuracy = report_test_svm["accuracy"]
nb_test_accuracy = report_test_nb["accuracy"]
knn_test_accuracy = report_test_knn["accuracy"]
dt_test_accuracy = report_test_dt["accuracy"]
mlp_test_accuracy = report_test_mlp["accuracy"]
# Plotting
plt.figure(figsize=(10, 6))
models = ["SVM", "Naïve Bayes", "KNN", "Decision Tree", "MLP"]
accuracies = [
    svm_test_accuracy,
    nb_test_accuracy,
    knn_test_accuracy,
    dt_test_accuracy,
    mlp_test_accuracy,
]

accuracies = [acc * 100 for acc in accuracies]  # Convert to percentages

colors = ["pink", "lightcoral", "orchid", "hotpink", "plum"]  # Girly colors

# Bar plot for testing accuracies
plt.bar(models, accuracies, color=colors, edgecolor="black")

# Annotate bars with accuracy values
for i, acc in enumerate(accuracies):
    plt.text(i, acc + 0.5, f"{acc:.2f}%", ha="center", fontsize=10, color="black")

plt.ylabel("Accuracy (%)")
plt.title("Testing Accuracy for Different Models")
plt.ylim(0, 105)  # Set y-axis limit to include annotations
plt.tight_layout()
plt.show()

# %% [markdown]
# # Save Models

# %%
import joblib
joblib.dump(best_dt_model, 'decision_tree_model.pkl')
joblib.dump(nb_model, 'naive_bayes_model.pkl')
joblib.dump(best_knn_model, 'knn_model.pkl')
joblib.dump(best_mlp_model, 'mlp_model.pkl')
joblib.dump(best_svm_model, 'svm_model.pkl')
# Out:
# ['svm_model.pkl']
