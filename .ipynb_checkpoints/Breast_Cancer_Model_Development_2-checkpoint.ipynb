# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import plot_tree

from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, classification_report, ConfusionMatrixDisplay

# %% [markdown]
# # Define Dataset

# %%
df = pd.read_csv("breast-cancer_cleaned.csv")
df
# Out:
#      texture_mean  symmetry_mean  fractal_dimension_mean  texture_se  \
# 0       -2.073335       2.217515                2.255747   -0.565265
# 1       -0.353632       0.001392               -0.868652   -0.876244
# 2        0.456187       0.939685               -0.398008   -0.780083
# 3        0.253732       0.155462                0.046836   -0.110409
# 4       -1.151816      -0.009560               -0.562450   -0.790244
# ..            ...            ...                     ...         ...
# 564      0.721473      -0.312589               -0.931027    0.071025
# 565      2.085134      -0.217664               -1.058611    0.322856
# 566      2.045574      -0.809117               -0.895587   -0.257371
# 567      2.336457       2.137194                1.043695    0.686088
# 568      1.221792      -0.820070               -0.561032    0.383092
#
#       area_se  smoothness_se  concavity_se  concave points_se  symmetry_se  \
# 0   -0.321821      -0.214002      0.724026           0.660820     1.148757
# 1    0.742402      -0.605351     -0.440780           0.260162    -0.805450
# 2    0.557852      -0.297005      0.213076           1.424827     0.237036
# 3   -0.288378       0.689702      0.819518           1.115007    -0.069777
# 4    0.156716       1.483067      0.828471           1.144205    -0.361092
# ..        ...            ...           ...                ...          ...
# 564  0.350640       1.086384      0.666001           2.067178    -1.138416
# 565 -0.131594      -0.424010      0.252202           0.808431    -0.189161
# 566  0.180698      -0.379342      0.510827           0.612157    -0.891416
# 567  0.183955      -0.173000      1.302285           0.785721     0.326634
# 568 -0.466152       0.049342     -1.057501          -1.913447     0.752830
#
#      fractal_dimension_se  smoothness_worst  symmetry_worst  \
# 0                0.907083          1.307686        1.139636
# 1               -0.099444         -0.375612       -0.243890
# 2                0.293559          0.527407        1.152255
# 3                0.267687          0.749217       -0.115114
# 4                0.499328          0.220556       -0.868353
# ..                    ...               ...             ...
# 564              0.167980          0.378365       -1.360158
# 565             -0.490556         -0.691230       -0.531855
# 566              0.036727         -0.809587       -1.104549
# 567              0.904057          1.430427        1.919083
# 568             -0.382754         -1.859019       -0.048138
#
#      fractal_dimension_worst  diagnosis
# 0                   1.937015          1
# 1                   0.281190          1
# 2                   0.201391          1
# 3                   0.230872          1
# 4                  -0.397100          1
# ..                       ...        ...
# 564                -0.709091          1
# 565                -0.973978          1
# 566                -0.318409          1
# 567                 0.936537          1
# 568                -0.751207          0
#
# [569 rows x 14 columns]

# %% [markdown]
# # Training Classifiers

# %% [markdown]
# ## Understand Dataset

# %%
df.head()
# Out:
#    texture_mean  symmetry_mean  fractal_dimension_mean  texture_se   area_se  \
# 0     -2.073335       2.217515                2.255747   -0.565265 -0.321821
# 1     -0.353632       0.001392               -0.868652   -0.876244  0.742402
# 2      0.456187       0.939685               -0.398008   -0.780083  0.557852
# 3      0.253732       0.155462                0.046836   -0.110409 -0.288378
# 4     -1.151816      -0.009560               -0.562450   -0.790244  0.156716
#
#    smoothness_se  concavity_se  concave points_se  symmetry_se  \
# 0      -0.214002      0.724026           0.660820     1.148757
# 1      -0.605351     -0.440780           0.260162    -0.805450
# 2      -0.297005      0.213076           1.424827     0.237036
# 3       0.689702      0.819518           1.115007    -0.069777
# 4       1.483067      0.828471           1.144205    -0.361092
#
#    fractal_dimension_se  smoothness_worst  symmetry_worst  \
# 0              0.907083          1.307686        1.139636
# 1             -0.099444         -0.375612       -0.243890
# 2              0.293559          0.527407        1.152255
# 3              0.267687          0.749217       -0.115114
# 4              0.499328          0.220556       -0.868353
#
#    fractal_dimension_worst  diagnosis
# 0                 1.937015          1
# 1                 0.281190          1
# 2                 0.201391          1
# 3                 0.230872          1
# 4                -0.397100          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   texture_mean             569 non-null    float64
#  1   symmetry_mean            569 non-null    float64
#  2   fractal_dimension_mean   569 non-null    float64
#  3   texture_se               569 non-null    float64
#  4   area_se                  569 non-null    float64
#  5   smoothness_se            569 non-null    float64
#  6   concavity_se             569 non-null    float64
#  7   concave points_se        569 non-null    float64
#  8   symmetry_se              569 non-null    float64
#  9   fractal_dimension_se     569 non-null    float64
#  10  smoothness_worst         569 non-null    float64
#  11  symmetry_worst           569 non-null    float64
#  12  fractal_dimension_worst  569 non-null    float64
#  13  diagnosis                569 non-null    int64
# dtypes: float64(13), int64(1)
# memory usage: 62.4 KB

# %% [markdown]
# **Dataset Overview**
#
# - **Number of Features:** 12
# - **Feature Types:**
#   - 5 categorical features
#   - 6 numerical features
# - **Target Type:**
#   - Numerical feature
# - **Missing Values:** None

# %% [markdown]
# **RestingBP** represents the resting blood pressure (mmHg).
# **Cholesterol** represents the serum cholesterol level (mg/dL).
# **FastingBS** indicates if fasting blood sugar is greater than 120 mg/dL.
# **RestingECG** results of the resting electrocardiogram test.
# **MaxHR** represents the maximum heart rate achieved.
# **ExerciseAngina** indicates if exercise-induced angina is present.
# **Oldpeak** represents the ST depression induced by exercise relative to rest (often used to measure ischemia).
# **ST_Slope** represents the slope of the peak exercise ST segment.
# **HeartDisease** is the target column

# %% [markdown]
# ## Descriptive Analysis

# %%
data = df.drop('HeartDisease', axis=1)
categorical_features = list(data.select_dtypes(include=['object']).columns)
numerical_features = list(data.select_dtypes(include=['number']).columns)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data = df.drop('HeartDisease', axis=1)
#       2 categorical_features = list(data.select_dtypes(include=['object']).columns)
#       3 numerical_features = list(data.select_dtypes(include=['number']).columns)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['HeartDisease'] not found in axis"

# %% [markdown]
# ### Numerical features

# %%
df.describe()

# %% [markdown]
# **Validate features Range**
#
# - **Age**: 0 to 120 years
#   **Validated**
#
# - **RestingBP (Resting Blood Pressure)**: 0 to 250 mmHg
#   - Typical systolic blood pressure values.
#   - *Values below 90 or above 200 are clinically abnormal.*
#   **Validated**
#
# - **Cholesterol**: 0 to 600 mg/dL
#   - Normal and extreme clinical levels.
#   - *Values above 300 are rare and usually indicate a serious condition.*
#   **Max observed: 603**
#
# - **FastingBS (Fasting Blood Sugar)**: [0, 1]
#   - Binary indicator:
#     - `1` for fasting blood sugar > 120 mg/dL
#     - `0` otherwise.
#   **Validated**
#
# - **MaxHR (Maximum Heart Rate)**: 0 to 220 bpm
#   - Calculated roughly as 220 minus age, though extremes are possible.
#   - *Typical values range from 60 bpm (resting) to around 200 bpm (during exercise).*
#
#     **Validated**
#
# - **Oldpeak**: 0 to 6.5
#   - Represents ST depression or elevation, typically measured in mm.
#   - *Values above 5.0 are rare and clinically significant.*
#   **Negative values observed.**
#
# - **HeartDisease**: [0, 1]
#   - Binary indicator:
#     - `1` for presence of heart disease
#     - `0` for absence.

# %% [markdown]
# Values Outside the Expected Range:
#
# - **Cholesterol**: Expected range from 0 to 600 mg/dL, but **603 mg/dL** was observed.
# - **Oldpeak**: Expected range from 0 to 6.5, but **negative values** were observed.

# %% [markdown]
# #### Detect Outliers

# %%
def detect_outliers(df, feature, threshold=3):
    z_scores = zscore(df[feature])
    outliers = (z_scores > abs(threshold))
    print(f"{outliers.sum()} outliers detected in '{feature}':")
    print(df[feature][outliers])
    print("-" * 50)
    return df[feature][outliers]

# %%
numerical_outliers = {}    
for feature in numerical_features:
    numerical_outliers[feature] = detect_outliers(data, feature)

# %% [markdown]
# Since the outliers are meaningful and provide important insights (rare but valid in medical datasets),
# they might be retained in the dataset.

# %% [markdown]
# ### Categorical features

# %%
for col in df.select_dtypes(include='object').columns:
    print(col)
    print(df[col].unique())
    print()

# %% [markdown]
# **ChestPainType**:
# ATA (Atypical Angina),
# NAP (Non-Anginal Pain),
# ASY (Asymptomatic),
# TA (Typical Angina)

# %% [markdown]
# **RestingECG**:
# Normal,
# ST (ST-segment depression or elevation),
# LVH (Left Ventricular Hypertrophy)

# %% [markdown]
# #### Categories frequency

# %%
for col in df.select_dtypes(include='object').columns:
    print(df[col].value_counts())
    print()

# %% [markdown]
# #### Inspecting infrequent categories

# %%
def detect_infrequent_categories(df, feature, threshold = 0.05*len(df)):
    value_counts = df[feature].value_counts()
    infrequent = value_counts[value_counts < threshold].index
    return infrequent

# %%
categorical_outliers = {}
for feature in df.select_dtypes(include=['object']):
    olist = detect_infrequent_categories(df, feature)
    categorical_outliers[feature] = olist
categorical_outliers

# %% [markdown]
# No outliers in categorical columns

# %% [markdown]
# ## Drop duplicates

# %%
df.duplicated().sum()

# %% [markdown]
# We don't have duplicates

# %% [markdown]
# ### Split data into Train, Validation, and Test Sets

# %% [markdown]
# X = df.drop('diagnosis', axis = 1)
# y = df['diagnosis']
#
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=1)
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# %% [markdown]
# Split data into training (80%), testing (20%)
#
# Then training into training (80%), validation (20%)
#
# 64% training - 16% validation - 20% testing

# %% [markdown]
# ### Evaluation functions

# %%
def evaluate_model(y_true, y_pred, model_name):
    print(f"\n{model_name} Performance:")
    results = classification_report(y_true, y_pred)
    print(results)
    print("Accuracy:", accuracy_score(y_true, y_pred))

# %%
def print_metrics_from_labels(y_true, y_pred, model_name):
    # Confusion matrix
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    # Metrics calculations
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    sensitivity = recall_score(y_true, y_pred)  # Same as recall
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0  # Manual calc for specificity
    error_rate = 1 - accuracy

    # Print the metrics with model name
    print(f"Metrics for {model_name}:")
    print(f"Accuracy: {accuracy * 100:.2f}%")
    print(f"Error Rate: {error_rate * 100:.2f}%")
    print(f"Sensitivity (Recall): {sensitivity * 100:.2f}%")
    print(f"Specificity: {specificity * 100:.2f}%")
    print(f"Precision: {precision * 100:.2f}%")

# Example Usage
y_true = [1, 0, 1, 1, 0, 0, 1, 0, 0, 0]  # Replace with actual labels
y_pred = [0, 0, 1, 1, 0, 0, 0, 0, 1, 0]  # Replace with predicted labels
model_name = "Decision Tree Classifier"

print_metrics_from_labels(y_true, y_pred, model_name)
# Out:
# Metrics for Decision Tree Classifier:
# Accuracy: 70.00%
# Error Rate: 30.00%
# Sensitivity (Recall): 50.00%
# Specificity: 83.33%
# Precision: 66.67%

# %%
def plot_confusion_matrix(y_true, y_pred, model_name):
    cm = confusion_matrix(y_true, y_pred)
    cm_percentage = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100
    disp = ConfusionMatrixDisplay(confusion_matrix=cm_percentage, display_labels=np.unique(y_true))
    disp.plot(cmap='Blues', values_format=".2f")  # Display values with 2 decimal places
    plt.title(f"Confusion Matrix for {model_name} (Percentage)")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.show()

# %% [markdown]
# ### Function to plot training and validation accuracy from GridSearchCV results

# %%
def plot_hyperparameter_results(grid_search, model_name):
    # Extract results
    results = grid_search.cv_results_

    # Get mean training and validation scores
    mean_train_scores = results['mean_train_score']  # Training accuracy
    mean_val_scores = results['mean_test_score']    # Validation accuracy
    param_combinations = results['params']          # Hyperparameter combinations

    # Plot training and validation accuracy
    indices = np.arange(len(param_combinations))
    plt.figure(figsize=(20, 7))
    plt.plot(indices, mean_train_scores, marker='o', linestyle='-', color='blue', label='Training Accuracy')
    plt.plot(indices, mean_val_scores, marker='o', linestyle='--', color='orange', label='Validation Accuracy')

    # Add labels, legend, and grid
    plt.xlabel('Hyperparameter Configuration Index')
    plt.ylabel('Accuracy')
    plt.title(f'Training and Validation Accuracy vs. Hyperparameter Configuration ({model_name})')
    plt.xticks(indices, labels=indices)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()


    # Print the configurations and their scores
    for i, params in enumerate(param_combinations):
        print()
        print(f"Configuration {i}: {params}")
        print(f"   Training Accuracy: {mean_train_scores[i]:.4f}", f"\t\t   Validation Accuracy: {mean_val_scores[i]:.4f}")

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# ### Training

# %% [markdown]
# #### Split data into train - test sets

# %%
X = df.drop('diagnosis', axis = 1)
y = df['diagnosis']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# Split data into training (80%), testing (20%)

# %% [markdown]
# The training set will be splited into train - val to get best hyperparameters using cross validation.

# %% [markdown]
# #### Intialize model

# %%
# Initialize the Decision Tree model with a fixed random seed for reproducibility
dt_model = DecisionTreeClassifier(random_state=42)

# %% [markdown]
# #### Get best hyperparameters using grid search

# %%
# Hyperparameter grid for tuning the Decision Tree
dt_param_grid = {
    'criterion': ['gini', 'entropy'],     # Use both Gini impurity and entropy for splitting nodes
    'max_depth': [3, 4],               # Test different maximum depths of the tree
    'min_samples_split': [30, 35],        # Minimum samples required to split an internal node
    'min_samples_leaf': [5, 10, 15],      # Minimum samples required to be at a leaf node
    'ccp_alpha': [0.005, 0.02],            # Pruning parameter to control overfitting
    'max_features': [None, 'sqrt', 'log2']          # Added max features
}

# %%
# Set up GridSearchCV to tune hyperparameters with 5-fold cross-validation
dt_grid_search = GridSearchCV(
    estimator=dt_model,                 # Decision Tree model
    param_grid=dt_param_grid,           # Hyperparameter grid for tuning
    scoring='accuracy',                 # Evaluate model based on accuracy score
    cv=5,                               # 5-fold cross-validation
    return_train_score=True,            # Return training scores
    n_jobs=-1,                          # Use all CPU cores for parallel processing
    verbose=2                           # Display progress during the search
)

# %% [markdown]
# #### Fit model to get e best hyperparameters

# %%
dt_grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# C:\Users\L340 GAMING\AppData\Roaming\Python\Python310\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'ccp_alpha': [0.005, 0.02],
#                          'criterion': ['gini', 'entropy'], 'max_depth': [3, 4],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_leaf': [5, 10, 15],
#                          'min_samples_split': [30, 35]},
#              return_train_score=True, scoring='accuracy', verbose=2)

# %%
plot_hyperparameter_results(dt_grid_search, "Decision Tree")
# Out:
# Configuration 0: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9275 		   Validation Accuracy: 0.8967
#
# Configuration 1: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9275 		   Validation Accuracy: 0.8967
#
# Configuration 2: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9231 		   Validation Accuracy: 0.8967
#
# Configuration 3: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9231 		   Validation Accuracy: 0.8967
#
# Configuration 4: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9143 		   Validation Accuracy: 0.8659
#
# Configuration 5: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9143 		   Validation Accuracy: 0.8659
#
# Configuration 6: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9077 		   Validation Accuracy: 0.8725
#
# Configuration 7: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9033 		   Validation Accuracy: 0.8681
#
# Configuration 8: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9137 		   Validation Accuracy: 0.8813
#
# Configuration 9: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9137 		   Validation Accuracy: 0.8813
#
# Configuration 10: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9071 		   Validation Accuracy: 0.8813
#
# Configuration 11: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9071 		   Validation Accuracy: 0.8813
#
# Configuration 12: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9077 		   Validation Accuracy: 0.8725
#
# Configuration 13: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9033 		   Validation Accuracy: 0.8681
#
# Configuration 14: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9137 		   Validation Accuracy: 0.8813
#
# Configuration 15: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9137 		   Validation Accuracy: 0.8813
#
# Configuration 16: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9071 		   Validation Accuracy: 0.8813
#
# Configuration 17: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9071 		   Validation Accuracy: 0.8813
#
# Configuration 18: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9313 		   Validation Accuracy: 0.8901
#
# Configuration 19: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9297 		   Validation Accuracy: 0.8879
#
# Configuration 20: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9231 		   Validation Accuracy: 0.8967
#
# Configuration 21: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9231 		   Validation Accuracy: 0.8967
#
# Configuration 22: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9154 		   Validation Accuracy: 0.8747
#
# Configuration 23: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9148 		   Validation Accuracy: 0.8725
#
# Configuration 24: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9132 		   Validation Accuracy: 0.8593
#
# Configuration 25: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9154 		   Validation Accuracy: 0.8593
#
# Configuration 26: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9071 		   Validation Accuracy: 0.8747
#
# Configuration 27: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9077 		   Validation Accuracy: 0.8659
#
# Configuration 28: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.8945 		   Validation Accuracy: 0.8571
#
# Configuration 29: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.8989 		   Validation Accuracy: 0.8769
#
# Configuration 30: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9132 		   Validation Accuracy: 0.8593
#
# Configuration 31: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9154 		   Validation Accuracy: 0.8593
#
# Configuration 32: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9071 		   Validation Accuracy: 0.8747
#
# Configuration 33: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9077 		   Validation Accuracy: 0.8659
#
# Configuration 34: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.8945 		   Validation Accuracy: 0.8571
#
# Configuration 35: {'ccp_alpha': 0.005, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.8989 		   Validation Accuracy: 0.8769
#
# Configuration 36: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9264 		   Validation Accuracy: 0.8989
#
# Configuration 37: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9264 		   Validation Accuracy: 0.8989
#
# Configuration 38: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9225 		   Validation Accuracy: 0.8923
#
# Configuration 39: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9225 		   Validation Accuracy: 0.8923
#
# Configuration 40: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9159 		   Validation Accuracy: 0.8593
#
# Configuration 41: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9159 		   Validation Accuracy: 0.8593
#
# Configuration 42: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9126 		   Validation Accuracy: 0.8791
#
# Configuration 43: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9126 		   Validation Accuracy: 0.8791
#
# Configuration 44: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9121 		   Validation Accuracy: 0.8813
#
# Configuration 45: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9121 		   Validation Accuracy: 0.8813
#
# Configuration 46: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9055 		   Validation Accuracy: 0.8813
#
# Configuration 47: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9055 		   Validation Accuracy: 0.8813
#
# Configuration 48: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9126 		   Validation Accuracy: 0.8791
#
# Configuration 49: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9126 		   Validation Accuracy: 0.8791
#
# Configuration 50: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9121 		   Validation Accuracy: 0.8813
#
# Configuration 51: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9121 		   Validation Accuracy: 0.8813
#
# Configuration 52: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9055 		   Validation Accuracy: 0.8813
#
# Configuration 53: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9055 		   Validation Accuracy: 0.8813
#
# Configuration 54: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9308 		   Validation Accuracy: 0.8923
#
# Configuration 55: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9302 		   Validation Accuracy: 0.8901
#
# Configuration 56: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9269 		   Validation Accuracy: 0.8945
#
# Configuration 57: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9264 		   Validation Accuracy: 0.8923
#
# Configuration 58: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9165 		   Validation Accuracy: 0.8703
#
# Configuration 59: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9159 		   Validation Accuracy: 0.8681
#
# Configuration 60: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9148 		   Validation Accuracy: 0.8857
#
# Configuration 61: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9148 		   Validation Accuracy: 0.8835
#
# Configuration 62: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9088 		   Validation Accuracy: 0.8967
#
# Configuration 63: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9077 		   Validation Accuracy: 0.8945
#
# Configuration 64: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9044 		   Validation Accuracy: 0.9033
#
# Configuration 65: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9044 		   Validation Accuracy: 0.9033
#
# Configuration 66: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9148 		   Validation Accuracy: 0.8857
#
# Configuration 67: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9148 		   Validation Accuracy: 0.8835
#
# Configuration 68: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9088 		   Validation Accuracy: 0.8967
#
# Configuration 69: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9077 		   Validation Accuracy: 0.8945
#
# Configuration 70: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9044 		   Validation Accuracy: 0.9033
#
# Configuration 71: {'ccp_alpha': 0.005, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9044 		   Validation Accuracy: 0.9033
#
# Configuration 72: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9154 		   Validation Accuracy: 0.8879
#
# Configuration 73: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9154 		   Validation Accuracy: 0.8879
#
# Configuration 74: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9088 		   Validation Accuracy: 0.8769
#
# Configuration 75: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9088 		   Validation Accuracy: 0.8769
#
# Configuration 76: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9033 		   Validation Accuracy: 0.8615
#
# Configuration 77: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9033 		   Validation Accuracy: 0.8615
#
# Configuration 78: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.8890 		   Validation Accuracy: 0.8681
#
# Configuration 79: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.8890 		   Validation Accuracy: 0.8681
#
# Configuration 80: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.8984 		   Validation Accuracy: 0.8681
#
# Configuration 81: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.8984 		   Validation Accuracy: 0.8681
#
# Configuration 82: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.8962 		   Validation Accuracy: 0.8725
#
# Configuration 83: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.8962 		   Validation Accuracy: 0.8725
#
# Configuration 84: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.8890 		   Validation Accuracy: 0.8681
#
# Configuration 85: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.8890 		   Validation Accuracy: 0.8681
#
# Configuration 86: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.8984 		   Validation Accuracy: 0.8681
#
# Configuration 87: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.8984 		   Validation Accuracy: 0.8681
#
# Configuration 88: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.8962 		   Validation Accuracy: 0.8725
#
# Configuration 89: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.8962 		   Validation Accuracy: 0.8725
#
# Configuration 90: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9154 		   Validation Accuracy: 0.8879
#
# Configuration 91: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9154 		   Validation Accuracy: 0.8879
#
# Configuration 92: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9088 		   Validation Accuracy: 0.8769
#
# Configuration 93: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9088 		   Validation Accuracy: 0.8769
#
# Configuration 94: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9033 		   Validation Accuracy: 0.8615
#
# Configuration 95: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9033 		   Validation Accuracy: 0.8615
#
# Configuration 96: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.8978 		   Validation Accuracy: 0.8747
#
# Configuration 97: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9005 		   Validation Accuracy: 0.8791
#
# Configuration 98: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.8929 		   Validation Accuracy: 0.8857
#
# Configuration 99: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.8945 		   Validation Accuracy: 0.8791
#
# Configuration 100: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.8852 		   Validation Accuracy: 0.8615
#
# Configuration 101: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.8885 		   Validation Accuracy: 0.8681
#
# Configuration 102: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.8978 		   Validation Accuracy: 0.8747
#
# Configuration 103: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9005 		   Validation Accuracy: 0.8791
#
# Configuration 104: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.8929 		   Validation Accuracy: 0.8857
#
# Configuration 105: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.8945 		   Validation Accuracy: 0.8791
#
# Configuration 106: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.8852 		   Validation Accuracy: 0.8615
#
# Configuration 107: {'ccp_alpha': 0.02, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.8885 		   Validation Accuracy: 0.8681
#
# Configuration 108: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9264 		   Validation Accuracy: 0.8989
#
# Configuration 109: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9264 		   Validation Accuracy: 0.8989
#
# Configuration 110: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9225 		   Validation Accuracy: 0.8923
#
# Configuration 111: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9225 		   Validation Accuracy: 0.8923
#
# Configuration 112: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9115 		   Validation Accuracy: 0.8659
#
# Configuration 113: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9115 		   Validation Accuracy: 0.8659
#
# Configuration 114: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9093 		   Validation Accuracy: 0.8747
#
# Configuration 115: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9093 		   Validation Accuracy: 0.8747
#
# Configuration 116: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9088 		   Validation Accuracy: 0.8769
#
# Configuration 117: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9088 		   Validation Accuracy: 0.8769
#
# Configuration 118: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9044 		   Validation Accuracy: 0.8791
#
# Configuration 119: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9044 		   Validation Accuracy: 0.8791
#
# Configuration 120: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9093 		   Validation Accuracy: 0.8747
#
# Configuration 121: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9093 		   Validation Accuracy: 0.8747
#
# Configuration 122: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9088 		   Validation Accuracy: 0.8769
#
# Configuration 123: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9088 		   Validation Accuracy: 0.8769
#
# Configuration 124: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9044 		   Validation Accuracy: 0.8791
#
# Configuration 125: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9044 		   Validation Accuracy: 0.8791
#
# Configuration 126: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9302 		   Validation Accuracy: 0.8945
#
# Configuration 127: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9297 		   Validation Accuracy: 0.8923
#
# Configuration 128: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9269 		   Validation Accuracy: 0.8945
#
# Configuration 129: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9264 		   Validation Accuracy: 0.8923
#
# Configuration 130: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9115 		   Validation Accuracy: 0.8681
#
# Configuration 131: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9115 		   Validation Accuracy: 0.8681
#
# Configuration 132: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9132 		   Validation Accuracy: 0.8879
#
# Configuration 133: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9132 		   Validation Accuracy: 0.8857
#
# Configuration 134: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9071 		   Validation Accuracy: 0.9011
#
# Configuration 135: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9060 		   Validation Accuracy: 0.8989
#
# Configuration 136: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9044 		   Validation Accuracy: 0.9033
#
# Configuration 137: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9044 		   Validation Accuracy: 0.9033
#
# Configuration 138: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 30}
#    Training Accuracy: 0.9132 		   Validation Accuracy: 0.8879
#
# Configuration 139: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 35}
#    Training Accuracy: 0.9132 		   Validation Accuracy: 0.8857
#
# Configuration 140: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 30}
#    Training Accuracy: 0.9071 		   Validation Accuracy: 0.9011
#
# Configuration 141: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 10, 'min_samples_split': 35}
#    Training Accuracy: 0.9060 		   Validation Accuracy: 0.8989
#
# Configuration 142: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 30}
#    Training Accuracy: 0.9044 		   Validation Accuracy: 0.9033
#
# Configuration 143: {'ccp_alpha': 0.02, 'criterion': 'entropy', 'max_depth': 4, 'max_features': 'log2', 'min_samples_leaf': 15, 'min_samples_split': 35}
#    Training Accuracy: 0.9044 		   Validation Accuracy: 0.9033

# %%
# Get the best model based on the grid search
best_dt_model = dt_grid_search.best_estimator_
dt_grid_search.best_params_
# Out:
# {'ccp_alpha': 0.005,
#  'criterion': 'entropy',
#  'max_depth': 4,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 15,
#  'min_samples_split': 30}

# %%
dt_grid_search.best_index_
# Out:
# 64

# %% [markdown]
# ### Training Evaluation

# %% [markdown]
# #### Grid search best model validation accuracy

# %%
# Get the index of the best configuration
best_config_index = dt_grid_search.best_index_
best_val_accuracy = dt_grid_search.cv_results_['mean_test_score'][best_config_index]

# Print the best configuration and its corresponding accuracy
print(f"Validation accuracy for best configuration: {best_val_accuracy * 100:.2f}%")
# Out:
# Validation accuracy for best configuration: 90.33%

# %% [markdown]
# ##### Cross-validation accuracy after grid search

# %%
# Perform cross-validation
scores = cross_val_score(best_dt_model, X_train, y_train, cv=5, scoring='accuracy')
print("Cross-Validation Scores:", scores)
print("Mean Accuracy:", scores.mean())
# Out:
# Cross-Validation Scores: [0.92307692 0.84615385 0.93406593 0.89010989 0.92307692]
# Mean Accuracy: 0.9032967032967033

# %% [markdown]
# ### Testing Evaluation

# %% [markdown]
# #### Classification Report

# %%
# Predict labels for the test set using the best Decision Tree model
y_test_pred_dt = best_dt_model.predict(X_test)
# Evaluate the model on the test set
report_test_dt = evaluate_model(y_test, y_test_pred_dt, "Tuned Decision Tree")
# Out:
# Tuned Decision Tree Performance:
#               precision    recall  f1-score   support
#
#            0       0.82      0.92      0.87        72
#            1       0.82      0.67      0.74        42
#
#     accuracy                           0.82       114
#    macro avg       0.82      0.79      0.80       114
# weighted avg       0.82      0.82      0.82       114
#
# Accuracy: 0.8245614035087719

# %% [markdown]
# #### Confusion Matrix

# %%
# Plot the confusion matrix for the Decision Tree model on the test set
plot_confusion_matrix(y_test, y_test_pred_dt, "Tuned Decision Tree TESTING")

# %% [markdown]
# ### Plot Decision Tree

# %%
plt.figure(figsize=(30,15))
plot_tree(best_dt_model, filled=True, feature_names=X_train.columns, class_names=["Benign", "Malignant"], rounded=True, fontsize=15)

# Add a legend with colors for the classes
plt.legend(handles=[plt.Line2D([0], [0], marker='o', markerfacecolor=color, markersize=20) for color in ['orange', 'lightblue']], 
           labels=["Benign", "Malignant"], loc="best", fontsize=20)
plt.show()

# %% [markdown]
# ## KNN Classifier

# %% [markdown]
# ### Training

# %% [markdown]
# #### Hyperprameters tuning for KNN

# %%
# Define a dictionary for hyperparameter tuning
knn_param_grid = {
    # List of possible values for the number of neighbors to consider during classification
    'n_neighbors': [3, 5, 7, 9, 11],

    # Set the 'weights' parameter to 'uniform', meaning each neighbor has an equal weight in the prediction
    'weights': ['uniform'],

    # List of distance metrics to use when calculating the distance between data points
    'metric': ['euclidean', 'manhattan']
}

# %% [markdown]
# #### Grid Search for Hyperparameters

# %%
# Create KNN classifier model
knn_model = KNeighborsClassifier()

# Set up GridSearchCV to search for the best hyperparameters
knn_grid_search = GridSearchCV(
    estimator=knn_model,                # KNN model
    param_grid=knn_param_grid,          # Hyperparameter grid to search
    scoring='f1_weighted',              # Use F1 weighted score as evaluation metric
    cv=5,                               # 5-fold cross-validation
    return_train_score=True             # Return training scores
)

# %% [markdown]
# #### Fit model to get best hyperparameters

# %%
knn_grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'metric': ['euclidean', 'manhattan'],
#                          'n_neighbors': [3, 5, 7, 9, 11],
#                          'weights': ['uniform']},
#              return_train_score=True, scoring='f1_weighted')

# %% [markdown]
# #### Best Hyperparameters

# %%
best_knn_model = knn_grid_search.best_estimator_
knn_grid_search.best_params_
# Out:
# {'metric': 'manhattan', 'n_neighbors': 11, 'weights': 'uniform'}

# %% [markdown]
# #### Plot training and validation accuracy verses Hyperprameters Tuning

# %%
plot_hyperparameter_results(knn_grid_search, "KNN")

# %% [markdown]
# ### Training Evaluation

# %% [markdown]
# #### Classification Report

# %%
# Predict labels for the validation set using the best KNN model
y_val_pred_knn = best_knn_model.predict(X_val)
# Evaluate the performance of the tuned KNN model on validation set
evaluate_model(y_val, y_val_pred_knn, "Tuned KNN")
# Out:
# Tuned KNN Performance:
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.86        66
#            1       0.89      0.88      0.88        81
#
#     accuracy                           0.87       147
#    macro avg       0.87      0.87      0.87       147
# weighted avg       0.87      0.87      0.87       147
#
# Accuracy: 0.8707482993197279

# %% [markdown]
# #### Confusion Matrix

# %%
# Plot confusion matrix for KNN on the validation set
plot_confusion_matrix(y_val, y_val_pred_knn, "Tuned KNN VALIDATION")

# %% [markdown]
# ### Testing Evaluation

# %% [markdown]
# #### Classification Report

# %%
# Predict labels for the test set using the best KNN model
y_test_pred_knn = best_knn_model.predict(X_test)
# Evaluate the performance of the tuned KNN model on the test set
report_test_knn = evaluate_model(y_test, y_test_pred_knn, "Tuned KNN")
# Out:
# Tuned KNN Performance:
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86        74
#            1       0.92      0.89      0.90       110
#
#     accuracy                           0.89       184
#    macro avg       0.88      0.88      0.88       184
# weighted avg       0.89      0.89      0.89       184
#
# Accuracy: 0.8858695652173914

# %% [markdown]
# #### Confusion Matrix

# %%
# Plot confusion matrix for KNN on the test set
plot_confusion_matrix(y_test, y_test_pred_knn, "Tuned KNN TESTING")

# %% [markdown]
# ## Naive Bayes Classifier

# %% [markdown]
# ### Training

# %% [markdown]
# #### Hyperparameter tuning for Bayes

# %%
# Define hyperparameter grids for Naive Bayes
nb_param_grid = {'var_smoothing': [1e-9, 1e-8, 1e-7, 1e-6]}

# %%
# Set up GridSearchCV for Naïve Bayes
nb_model = GaussianNB()
nb_grid_search = GridSearchCV(estimator=nb_model, param_grid=nb_param_grid, scoring='f1_weighted', cv=5,return_train_score=True)

# %% [markdown]
# #### Fit model to get best hyperparameters

# %%
nb_grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=GaussianNB(),
#              param_grid={'var_smoothing': [1e-09, 1e-08, 1e-07, 1e-06]},
#              return_train_score=True, scoring='f1_weighted')

# %% [markdown]
# #### Get best parameters

# %%
print("Best parameters for Naïve Bayes:", nb_grid_search.best_params_)
best_nb_model = nb_grid_search.best_estimator_
y_val_pred_nb = best_nb_model.predict(X_val)
# Out:
# Best parameters for Naïve Bayes: {'var_smoothing': 1e-09}

# %% [markdown]
# #### Plot training and validation accuracy verses Hyperprameters Tuning

# %%
plot_hyperparameter_results(nb_grid_search, "Naive Bayes")

# %% [markdown]
# ### Training Evaluation

# %% [markdown]
# #### Classification Report

# %%
evaluate_model(y_val, y_val_pred_nb, "Tuned Naïve Bayes")
# Out:
# Tuned Naïve Bayes Performance:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85        66
#            1       0.90      0.85      0.87        81
#
#     accuracy                           0.86       147
#    macro avg       0.86      0.87      0.86       147
# weighted avg       0.87      0.86      0.86       147
#
# Accuracy: 0.8639455782312925

# %% [markdown]
# #### Confusion Matrix

# %%
plot_confusion_matrix(y_val, y_val_pred_nb, "Tuned Naïve Bayes")

# %% [markdown]
# ### Testing Evaluation

# %% [markdown]
# #### Classification report

# %%
y_test_pred_nb = best_nb_model.predict(X_test)
report_test_nb = evaluate_model(y_test, y_test_pred_nb, "Tuned Naïve Bayes")
# Out:
# Tuned Naïve Bayes Performance:
#               precision    recall  f1-score   support
#
#            0       0.86      0.88      0.87        74
#            1       0.92      0.90      0.91       110
#
#     accuracy                           0.89       184
#    macro avg       0.89      0.89      0.89       184
# weighted avg       0.89      0.89      0.89       184
#
# Accuracy: 0.8913043478260869

# %% [markdown]
# #### Confusion Matrix

# %%
plot_confusion_matrix(y_test, y_test_pred_nb, "Tuned Naïve Bayes")

# %% [markdown]
# ## Models Comparisions

# %%
# Extract weighted average metrics
metrics = ["precision", "recall", "f1-score"]
x_labels = ["Precision", "Recall", "F1-Score"]

# %%
# To plot histogram
x = np.arange(len(metrics))
width = 0.15

# %% [markdown]
# ### Validation Weighted Metrics

# %%
### Classification reports for validation
report_val_svm = classification_report(y_val, y_val_pred_svm, output_dict=True)
report_val_nb = classification_report(y_val, y_val_pred_nb, output_dict=True)
report_val_knn = classification_report(y_val, y_val_pred_knn, output_dict=True)
report_val_dt = classification_report(y_val, y_val_pred_dt, output_dict=True)

# %%
# Validation metrics
svm_val_metrics = [report_val_svm["weighted avg"][metric] for metric in metrics]
nb_val_metrics = [report_val_nb["weighted avg"][metric] for metric in metrics]
knn_val_metrics = [report_val_knn["weighted avg"][metric] for metric in metrics]
dt_val_metrics = [report_val_dt["weighted avg"][metric] for metric in metrics]

# %%
plt.figure(figsize=(12, 6))
plt.bar(x - 1.5 * width, svm_val_metrics, width, label="SVM (Validation)", color='pink')
plt.bar(x - 0.5 * width, nb_val_metrics, width, label="Naïve Bayes (Validation)", color='brown')
plt.bar(x + 0.5 * width, knn_val_metrics, width, label="KNN (Validation)", color='green')
plt.bar(x + 1.5 * width, dt_val_metrics, width, label="Decision Tree (Validation)", color='orange')

plt.ylabel("Score")
plt.title("Weighted Metrics - Validation Set")
plt.xticks(x, x_labels)
plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Testing Weighted Metrics

# %%
# classification reports for testing
report_test_svm = classification_report(y_test, y_test_pred_svm, output_dict=True)
report_test_nb = classification_report(y_test, y_test_pred_nb, output_dict=True)
report_test_knn = classification_report(y_test, y_test_pred_knn, output_dict=True)
report_test_dt = classification_report(y_test, y_test_pred_dt, output_dict=True)

# %%
# Testing metrics
svm_test_metrics = [report_test_svm["weighted avg"][metric] for metric in metrics]
nb_test_metrics = [report_test_nb["weighted avg"][metric] for metric in metrics]
knn_test_metrics = [report_test_knn["weighted avg"][metric] for metric in metrics]
dt_test_metrics = [report_test_dt["weighted avg"][metric] for metric in metrics]

# %%
plt.figure(figsize=(12, 6))
plt.bar(x - 1.5 * width, svm_test_metrics, width, label="SVM (Testing)", color='blue')
plt.bar(x - 0.5 * width, nb_test_metrics, width, label="Naïve Bayes (Testing)", color='cyan')
plt.bar(x + 0.5 * width, knn_test_metrics, width, label="KNN (Testing)", color='purple')
plt.bar(x + 1.5 * width, dt_test_metrics, width, label="Decision Tree (Testing)", color='red')

plt.ylabel("Score")
plt.title("Weighted Metrics - Testing Set")
plt.xticks(x, x_labels)
plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Dendogram

# %% [markdown]
# ### Function to Plot Dendogram

# %%
def plot_dendrogram(X, method):
    # Compute the linkage matrix for hierarchical clustering
    linkage_matrix = linkage(X, method=method)

    # Plot the dendrogram
    plt.figure(figsize=(10, 6))
    plt.title(f'Hierarchical Clustering Dendrogram ({method.capitalize()} Linkage)')
    plt.xlabel('Data Points or Clusters')
    plt.ylabel('Dissimilarity (Distance)')

    # Create the dendrogram plot with truncated visualization for simplicity
    dendrogram(
        linkage_matrix,
        truncate_mode='level',  # Limit the levels of hierarchy shown
        p=5,                    # Show top 5 levels
        leaf_rotation=90,       # Rotate leaf labels for better readability
        leaf_font_size=10,      # Font size for leaf labels
        show_contracted=True    # Contract large branches for readability
    )
    plt.show()
    
    return linkage_matrix

# %% [markdown]
# ### Single linkage dendogram

# %%
single_linkage = plot_dendrogram(X, 'single')

# %% [markdown]
# ### Complete linkage dendogram

# %%
complete_linkage = plot_dendrogram(X, 'complete')

# %% [markdown]
# ### Average linkage dendogram

# %%
avg_linkage = plot_dendrogram(X, 'average')

# %% [markdown]
# ### Centroid linkage dendogram

# %%
centroid_linkage = plot_dendrogram(X, 'centroid')

# %% [markdown]
# ### Ward linkage dendogram

# %%
ward_linkage = plot_dendrogram(X, 'ward')

# %% [markdown]
# ### Function to compare clusters with target column

# %%
# Add cluster labels and target labels to a DataFrame for comparison
def compare_clusters_with_target(cluster_labels):
    comparison_df = pd.DataFrame({
        'Cluster': cluster_labels,
        'Target': y
    })

    # Evaluate clustering performance
    # Count the number of data points in each cluster-target combination
    cluster_target_counts = comparison_df.groupby(['Cluster', 'Target']).size().unstack(fill_value=0)

    print("Cluster vs. Target Comparison:")
    print(cluster_target_counts)

    # Visualize the comparison
    cluster_target_counts.plot(kind='bar', stacked=True, figsize=(10, 6), colormap='viridis')
    plt.title('Cluster vs. Target Distribution')
    plt.xlabel('Cluster')
    plt.ylabel('Count')
    plt.legend(title='Target')
    plt.show()

# %% [markdown]
# ### Plot histogram to compare result clusters with target column

# %%
num_clusters = 2
# yes, no

# %% [markdown]
# #### Single Linkage

# %%
# Perform hierarchical clustering to get cluster labels using single linkage method
cluster_labels_Single = fcluster(single_linkage, num_clusters, criterion='maxclust')

# Compare the clusters with the actual target labels and visualize the distribution
compare_clusters_with_target(cluster_labels_Single)
# Out:
# Cluster vs. Target Comparison:
# Target     0    1
# Cluster
# 1        410  507
# 2          0    1

# %% [markdown]
# #### Complete Linkage

# %%
# Perform hierarchical clustering to get cluster labels using complete linkage method
cluster_labels_complete = fcluster(complete_linkage, num_clusters, criterion='maxclust')

# Compare the clusters with the actual target labels and visualize the distribution
compare_clusters_with_target(cluster_labels_complete)
# Out:
# Cluster vs. Target Comparison:
# Target     0    1
# Cluster
# 1        410  507
# 2          0    1

# %% [markdown]
# #### Average Linkage

# %%
# Perform hierarchical clustering to get cluster labels using average linkage method
cluster_labels_average = fcluster(avg_linkage, num_clusters, criterion='maxclust')

# Compare the clusters with the actual target labels and visualize the distribution
compare_clusters_with_target(cluster_labels_average)
# Out:
# Cluster vs. Target Comparison:
# Target     0    1
# Cluster
# 1        410  507
# 2          0    1

# %% [markdown]
# #### Centroid Linkage

# %%
# Perform hierarchical clustering to get cluster labels using centroid linkage method
cluster_labels_centroid = fcluster(centroid_linkage, num_clusters, criterion='maxclust')

# Compare the clusters with the actual target labels and visualize the distribution
compare_clusters_with_target(cluster_labels_centroid)
# Out:
# Cluster vs. Target Comparison:
# Target     0    1
# Cluster
# 1        410  507
# 2          0    1

# %% [markdown]
# #### Ward Linkage

# %%
# Perform hierarchical clustering to get cluster labels using ward linkage method
cluster_labels_ward = fcluster(ward_linkage, num_clusters, criterion='maxclust')

# Compare the clusters with the actual target labels and visualize the distribution
compare_clusters_with_target(cluster_labels_ward)
# Out:
# Cluster vs. Target Comparison:
# Target     0    1
# Cluster
# 1        307  102
# 2        103  406

# %% [markdown]
# **Looking at all linkages we found out their is an outlier index 449 that need to be removed.**
